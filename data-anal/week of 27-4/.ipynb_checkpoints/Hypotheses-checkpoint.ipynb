# %%
# Hypothesis Set-up Doc

# %%
# Package Loading
#suppressPackageStartupMessages(library(rvg))
suppressPackageStartupMessages(library(broom))
#suppressPackageStartupMessages(library(officer))
#suppressPackageStartupMessages(library(flextable))
suppressPackageStartupMessages(library(sensitivity))
suppressPackageStartupMessages(library(broom.mixed))
suppressPackageStartupMessages(library(lm.beta))
#suppressPackageStartupMessages(library(igraph))
#suppressPackageStartupMessages(library(ggraph))
suppressPackageStartupMessages(library(janitor))
#suppressPackageStartupMessages(library(tidygraph))
suppressPackageStartupMessages(library(patchwork))
suppressPackageStartupMessages(library(knitr))
suppressPackageStartupMessages(library(ComplexUpset)) 
suppressPackageStartupMessages(library(plotly)) ## matplotlib dynamic ggplot object
suppressPackageStartupMessages(library(DT)) # use to dynamically render datatables
suppressPackageStartupMessages(library(lme4))
suppressPackageStartupMessages(library(lmerTest))
suppressPackageStartupMessages(library(performance))
suppressPackageStartupMessages(library(ranger))
suppressPackageStartupMessages(library(arrow))
suppressPackageStartupMessages(library(see))
suppressPackageStartupMessages(library(tidyverse))
suppressPackageStartupMessages(library(duckplyr))

# core optimization
options(ranger.num.threads = 4)
duckplyr::db_exec("PRAGMA threads=4;")
# Out:
# duckdb keeps downloaded extensions and secrets in a temporary directory:
# ℹ /tmp/RtmpuA4noC/duckdb
# This is removed when the R session ends.
# • Extensions are re-downloaded each session.
# • Secrets are lost.
# ℹ Run duckdb(shared_home = TRUE) (or create ~/.duckdb) to keep them (suitable for most users).
# ℹ Run duckdb(shared_home = FALSE) to accept the temporary directory (and silence this message).
# ℹ See ?duckdb_storage for details and alternatives.

# %%
# Sourcing Helpers and Files
source("./functions.R")
source("./data_processing.R")
source("./plots.R")

# %%
# Compilation of LHS, GA and Validation
##### -------
# IN THIS VERSION OF CONFIG ALL DEBATES ARE CONSIDERED FOR LSH AND GA (EXCLUDING CONTROLS)
# THE DATA FOR LHS AND GA ARE CALIBRATED ON 43 DEBATES AND VALIDATED ON 12 HELD-OUT DEBATES
##### -------
source("./framework_analysis.R")
df_empirical <- empirical_prep("./data/data_complete_anonymised.csv")
# result_lhs_train <- process_run(lhs)
result_ga_train <- process_run(ga)
result_ga_val <- process_run(val)

# LHS
# lhs_bundle <- list(
#   sim_inputs = result_lhs_train,
#   df_empirical = df_empirical
# )

# lhs_outputs <- analyze_processed_run(lhs_bundle)

# GA & VAL
ga_bundle <- list(
  sim_inputs = result_ga_train,
  sim_val    = result_ga_val,
  df_empirical = df_empirical
)

ga_outputs <- analyze_processed_run(ga_bundle)
# Out:
# lazy data frame collected and pulled into R memory, starting col coercion and NA diagnostics
#
# no missing required columns, proceeding with mutations
# [10:44:53] Char and Logical Col coercion finished, starting NA diagnostics...
#              model_type       current_condition      selected_debate_id
#                       0                       0                       0
#            debate_label   current_experiment_id              max_cycles
#                       0                       0                       0
#               converged     use_distinct_agents           speaking_mode
#                       0                       0                       0
#       logged_batch_seed               pro_count              anti_count
#                       0                       0                       0
#        convergence_rate    confidence_threshold     repulsion_threshold
#                       0                       0                       0
#      repulsion_strength     convergence_rate_sd confidence_threshold_sd
#                       0                       0                       0
#  repulsion_threshold_sd   repulsion_strength_sd       convergence_cycle
#                       0                       0                       0
#        initial_variance                     mae        opinion_variance
#                       0                       0                       0
#      polarization_index            num_clusters    initial_num_clusters
#                       0                       0                       0
#      neutral_zone_width  mean_net_repulsion_abs  normalised_convergence
#                       0                       0                       0
#      debate_composition                    seed
#                       0                       0
# [1] 0
# No NA values in rows or columns
#
# No violations found, good on ya ;-+
# [10:45:22] Starting Agent Loading Block
# lazy data frame collected and pulled into R memory, starting col coercion and NA diagnostics
#
# no missing required columns, proceeding with mutations
# [10:50:49] Char and Logical Col coercion finished, starting NA diagnostics...
#                 model_type          current_condition
#                          0                          0
#         selected_debate_id               debate_label
#                          0                          0
#      current_experiment_id                 max_cycles
#                          0                          0
#        use_distinct_agents              speaking_mode
#                          0                          0
#          logged_batch_seed                   agent_id
#                          0                          0
#              pro_reduction                  pro_count
#                          0                          0
#                 anti_count             subfactor_1_t1
#                          0                          0
#             subfactor_2_t1             subfactor_3_t1
#                          0                          0
#             subfactor_4_t1             subfactor_5_t1
#                          0                          0
#            initial_opinion           initial_variance
#                          0                          0
#                    opinion             subfactor_1_t2
#                          0                          0
#             subfactor_2_t2             subfactor_3_t2
#                          0                          0
#             subfactor_4_t2             subfactor_5_t2
#                          0                          0
#             final_attitude         mean_t2_subfactors
#                          0                          0
#             opinion_change           individual_error
#                          0                          0
#                 error_sub1                 error_sub2
#                          0                          0
#                 error_sub3                 error_sub4
#                          0                          0
#                 error_sub5     agent_convergence_rate
#                          0                          0
# agent_confidence_threshold  agent_repulsion_threshold
#                          0                          0
#   agent_repulsion_strength  total_influences_received
#                          0                          0
#         retention_discount  cumulative_opinion_change
#                          0                          0
#           agent_net_change      agent_wrong_direction
#                          0                          0
#         agent_is_saturated           convergence_rate
#                          0                          0
#       confidence_threshold        repulsion_threshold
#                          0                          0
#         repulsion_strength          convergence_cycle
#                          0                          0
#                  converged     normalised_convergence
#                          0                          0
#         debate_composition                       seed
#                          0                          0
# [1] 0
# No NA values in rows or columns
#
# Skipping neutral zone validation: columns not in dataset
# [10:53:28] Starting Directional dfs, unsummarized
# [10:53:47] Starting summarized Directional df
# [10:53:54] Starting Valence Analysis Chunk: summarized valence for models first
# [10:54:04] Upset df calculation starting...
# [10:54:04] Bias flag computation for df_valence starting
# lazy data frame collected and pulled into R memory, starting col coercion and NA diagnostics
#
# no missing required columns, proceeding with mutations
# [10:54:05] Char and Logical Col coercion finished, starting NA diagnostics...
#              model_type       current_condition      selected_debate_id
#                       0                       0                       0
#            debate_label   current_experiment_id              max_cycles
#                       0                       0                       0
#               converged     use_distinct_agents           speaking_mode
#                       0                       0                       0
#       logged_batch_seed               pro_count              anti_count
#                       0                       0                       0
#        convergence_rate    confidence_threshold     repulsion_threshold
#                       0                       0                       0
#      repulsion_strength     convergence_rate_sd confidence_threshold_sd
#                       0                       0                       0
#  repulsion_threshold_sd   repulsion_strength_sd       convergence_cycle
#                       0                       0                       0
#        initial_variance                     mae        opinion_variance
#                       0                       0                       0
#      polarization_index            num_clusters    initial_num_clusters
#                       0                       0                       0
#      neutral_zone_width  mean_net_repulsion_abs  normalised_convergence
#                       0                       0                       0
#      debate_composition                    seed
#                       0                       0
# [1] 0
# No NA values in rows or columns
#
# No violations found, good on ya ;-+
# [10:54:05] Starting Agent Loading Block
# lazy data frame collected and pulled into R memory, starting col coercion and NA diagnostics
#
# no missing required columns, proceeding with mutations
# [10:54:11] Char and Logical Col coercion finished, starting NA diagnostics...
#                 model_type          current_condition
#                          0                          0
#         selected_debate_id               debate_label
#                          0                          0
#      current_experiment_id                 max_cycles
#                          0                          0
#        use_distinct_agents              speaking_mode
#                          0                          0
#          logged_batch_seed                   agent_id
#                          0                          0
#              pro_reduction                  pro_count
#                          0                          0
#                 anti_count             subfactor_1_t1
#                          0                          0
#             subfactor_2_t1             subfactor_3_t1
#                          0                          0
#             subfactor_4_t1             subfactor_5_t1
#                          0                          0
#            initial_opinion           initial_variance
#                          0                          0
#                    opinion             subfactor_1_t2
#                          0                          0
#             subfactor_2_t2             subfactor_3_t2
#                          0                          0
#             subfactor_4_t2             subfactor_5_t2
#                          0                          0
#             final_attitude         mean_t2_subfactors
#                          0                          0
#             opinion_change           individual_error
#                          0                          0
#                 error_sub1                 error_sub2
#                          0                          0
#                 error_sub3                 error_sub4
#                          0                          0
#                 error_sub5     agent_convergence_rate
#                          0                          0
# agent_confidence_threshold  agent_repulsion_threshold
#                          0                          0
#   agent_repulsion_strength  total_influences_received
#                          0                          0
#         retention_discount  cumulative_opinion_change
#                          0                          0
#           agent_net_change      agent_wrong_direction
#                          0                          0
#         agent_is_saturated           convergence_rate
#                          0                          0
#       confidence_threshold        repulsion_threshold
#                          0                          0
#         repulsion_strength          convergence_cycle
#                          0                          0
#                  converged     normalised_convergence
#                          0                          0
#         debate_composition                       seed
#                          0                          0
# [1] 0
# No NA values in rows or columns
#
# Skipping neutral zone validation: columns not in dataset
# [10:54:13] Starting Directional dfs, unsummarized
# [10:54:13] Starting summarized Directional df
# [10:54:13] Starting Valence Analysis Chunk: summarized valence for models first
# [10:54:13] Upset df calculation starting...
# [10:54:13] Bias flag computation for df_valence starting
# lazy data frame collected and pulled into R memory, starting col coercion and NA diagnostics
#
# no missing required columns, proceeding with mutations
# [10:54:14] Char and Logical Col coercion finished, starting NA diagnostics...
#              model_type       current_condition      selected_debate_id
#                       0                       0                       0
#            debate_label   current_experiment_id              max_cycles
#                       0                       0                       0
#               converged     use_distinct_agents           speaking_mode
#                       0                       0                       0
#       logged_batch_seed               pro_count              anti_count
#                       0                       0                       0
#        convergence_rate    confidence_threshold     repulsion_threshold
#                       0                       0                       0
#      repulsion_strength     convergence_rate_sd confidence_threshold_sd
#                       0                       0                       0
#  repulsion_threshold_sd   repulsion_strength_sd       convergence_cycle
#                       0                       0                       0
#        initial_variance                     mae        opinion_variance
#                       0                       0                       0
#      polarization_index            num_clusters    initial_num_clusters
#                       0                       0                       0
#      neutral_zone_width  mean_net_repulsion_abs  normalised_convergence
#                       0                       0                       0
#      debate_composition                    seed
#                       0                       0
# [1] 0
# No NA values in rows or columns
#
# No violations found, good on ya ;-+
# [10:54:14] Starting Agent Loading Block
# lazy data frame collected and pulled into R memory, starting col coercion and NA diagnostics
#
# no missing required columns, proceeding with mutations
# [10:54:15] Char and Logical Col coercion finished, starting NA diagnostics...
#                 model_type          current_condition
#                          0                          0
#         selected_debate_id               debate_label
#                          0                          0
#      current_experiment_id                 max_cycles
#                          0                          0
#        use_distinct_agents              speaking_mode
#                          0                          0
#          logged_batch_seed                   agent_id
#                          0                          0
#              pro_reduction                  pro_count
#                          0                          0
#                 anti_count             subfactor_1_t1
#                          0                          0
#             subfactor_2_t1             subfactor_3_t1
#                          0                          0
#             subfactor_4_t1             subfactor_5_t1
#                          0                          0
#            initial_opinion           initial_variance
#                          0                          0
#                    opinion             subfactor_1_t2
#                          0                          0
#             subfactor_2_t2             subfactor_3_t2
#                          0                          0
#             subfactor_4_t2             subfactor_5_t2
#                          0                          0
#             final_attitude         mean_t2_subfactors
#                          0                          0
#             opinion_change           individual_error
#                          0                          0
#                 error_sub1                 error_sub2
#                          0                          0
#                 error_sub3                 error_sub4
#                          0                          0
#                 error_sub5     agent_convergence_rate
#                          0                          0
# agent_confidence_threshold  agent_repulsion_threshold
#                          0                          0
#   agent_repulsion_strength  total_influences_received
#                          0                          0
#         retention_discount  cumulative_opinion_change
#                          0                          0
#           agent_net_change      agent_wrong_direction
#                          0                          0
#         agent_is_saturated           convergence_rate
#                          0                          0
#       confidence_threshold        repulsion_threshold
#                          0                          0
#         repulsion_strength          convergence_cycle
#                          0                          0
#                  converged     normalised_convergence
#                          0                          0
#         debate_composition                       seed
#                          0                          0
# [1] 0
# No NA values in rows or columns
#
# Skipping neutral zone validation: columns not in dataset
# [10:54:15] Starting Directional dfs, unsummarized
# [10:54:17] Starting summarized Directional df
# [10:54:17] Starting Valence Analysis Chunk: summarized valence for models first
# [10:54:17] Upset df calculation starting...
# [10:54:17] Bias flag computation for df_valence starting
# [10:54:18] Starting Empirical model MLM for beta calculations...
# [10:54:18] Finished empirical MLM
# [10:54:18] Starting H2 uncentered model...
# boundary (singular) fit: see help('isSingular')
# [10:54:18] Finished H2 uncentered model...
# [10:54:18] Starting H2 centered model...
# boundary (singular) fit: see help('isSingular')
# [10:54:18] Finished H2 centered model...
# piece rows: 34400
# key: bipolarization_FALSE_nospeak | lookup: bipolarization_FALSE | in param_cols_by_model: TRUE
# rf_data rows for bipolarization_FALSE_nospeak mae : 34400
# rf_data rows for bipolarization_FALSE_nospeak opinion_variance : 34400
# rf_data rows for bipolarization_FALSE_nospeak convergence_cycle : 34400
# piece rows: 172000
#   subsampled to: 50000
# key: bipolarization_FALSE_speak | lookup: bipolarization_FALSE | in param_cols_by_model: TRUE
# rf_data rows for bipolarization_FALSE_speak mae : 50000
# rf_data rows for bipolarization_FALSE_speak opinion_variance : 50000
# rf_data rows for bipolarization_FALSE_speak convergence_cycle : 50000
# piece rows: 344000
#   subsampled to: 50000
# key: bipolarization_TRUE_nospeak | lookup: bipolarization_TRUE | in param_cols_by_model: TRUE
# rf_data rows for bipolarization_TRUE_nospeak mae : 50000
# rf_data rows for bipolarization_TRUE_nospeak opinion_variance : 50000
# rf_data rows for bipolarization_TRUE_nospeak convergence_cycle : 50000
# piece rows: 344000
#   subsampled to: 50000
# key: bipolarization_TRUE_speak | lookup: bipolarization_TRUE | in param_cols_by_model: TRUE
# rf_data rows for bipolarization_TRUE_speak mae : 50000
# rf_data rows for bipolarization_TRUE_speak opinion_variance : 50000
# rf_data rows for bipolarization_TRUE_speak convergence_cycle : 50000
# piece rows: 17200
# key: clustering_FALSE_nospeak | lookup: clustering_FALSE | in param_cols_by_model: TRUE
# rf_data rows for clustering_FALSE_nospeak mae : 17200
# rf_data rows for clustering_FALSE_nospeak opinion_variance : 17200
# rf_data rows for clustering_FALSE_nospeak convergence_cycle : 17200
# piece rows: 86000
#   subsampled to: 50000
# key: clustering_FALSE_speak | lookup: clustering_FALSE | in param_cols_by_model: TRUE
# rf_data rows for clustering_FALSE_speak mae : 50000
# rf_data rows for clustering_FALSE_speak opinion_variance : 50000
# rf_data rows for clustering_FALSE_speak convergence_cycle : 50000
# piece rows: 172000
#   subsampled to: 50000
# key: clustering_TRUE_nospeak | lookup: clustering_TRUE | in param_cols_by_model: TRUE
# rf_data rows for clustering_TRUE_nospeak mae : 50000
# rf_data rows for clustering_TRUE_nospeak opinion_variance : 50000
# rf_data rows for clustering_TRUE_nospeak convergence_cycle : 50000
# piece rows: 172000
#   subsampled to: 50000
# key: clustering_TRUE_speak | lookup: clustering_TRUE | in param_cols_by_model: TRUE
# rf_data rows for clustering_TRUE_speak mae : 50000
# rf_data rows for clustering_TRUE_speak opinion_variance : 50000
# rf_data rows for clustering_TRUE_speak convergence_cycle : 50000
# piece rows: 8600
# key: consensus_FALSE_nospeak | lookup: consensus_FALSE | in param_cols_by_model: TRUE
# rf_data rows for consensus_FALSE_nospeak mae : 8600
# rf_data rows for consensus_FALSE_nospeak opinion_variance : 8600
# rf_data rows for consensus_FALSE_nospeak convergence_cycle : 8600
# piece rows: 43000
# key: consensus_FALSE_speak | lookup: consensus_FALSE | in param_cols_by_model: TRUE
# rf_data rows for consensus_FALSE_speak mae : 43000
# rf_data rows for consensus_FALSE_speak opinion_variance : 43000
# piece rows: 86000
#   subsampled to: 50000
# key: consensus_TRUE_nospeak | lookup: consensus_TRUE | in param_cols_by_model: TRUE
# rf_data rows for consensus_TRUE_nospeak mae : 50000
# rf_data rows for consensus_TRUE_nospeak opinion_variance : 50000
# rf_data rows for consensus_TRUE_nospeak convergence_cycle : 50000
# piece rows: 86000
#   subsampled to: 50000
# key: consensus_TRUE_speak | lookup: consensus_TRUE | in param_cols_by_model: TRUE
# rf_data rows for consensus_TRUE_speak mae : 50000
# rf_data rows for consensus_TRUE_speak opinion_variance : 50000
# rf_data rows for consensus_TRUE_speak convergence_cycle : 50000
# [10:58:10] DEBUG: sucessfully entered df_ag mutation block before lmer calculations
# [10:58:10] OLS vs ABM comparison initial mutation complete, starting df_ag slicing
# [DIAGNOSTIC] Starting empirical MLM pipeline...
#
#  -> Initial df_ag rows: 7607809
#
#  -> Unique 'current_condition' levels (2): homogeneous, heterogeneous
#
#  -> Unique 'debate_label' count: 43
# [11:03:03] starting H1a df creation
# [11:03:14] Finished df creation, now starting H1a mlm...
# boundary (singular) fit: see help('isSingular')
# [11:03:14] H1b df setup starting...
# [11:03:20] Finished H1b df setup, starting mlm...
# boundary (singular) fit: see help('isSingular')
# [11:04:01] H1b df setup starting...
# [11:04:04] Finished H1b df setup, starting mlm...
# boundary (singular) fit: see help('isSingular')
# [11:04:31] H1b df setup starting...
# [11:04:33] Finished H1b df setup, starting mlm...
# boundary (singular) fit: see help('isSingular')
# [11:04:44] Skipping H1b for no_change - T1 equals T2 by definition
# [11:04:44] Skipping H3 Benchmark and H5 set up, no validation data in bundle
# [11:04:44] Starting branch C df setups, ols vs abm...
# [11:04:59] finished ols vs abm delta_mae calculations, starting empirical and simulated betas...
# DEBUG - complete cases count:
#
# DEBUG - df_conv_debate speaking_mode table:
# FALSE  TRUE  <NA>
#   172   129     0
# [1] 258
# Notice: GAML GA bounds extraction started
# [1] "WARNING: the following parameters have ranges too narrow for follow up algorithm search:"
# # A tibble: 38 × 26
#    model_type     use_distinct_agents speaking_mode  cr_min cr_max cr_max_sd
#  * <chr>          <lgl>               <lgl>           <dbl>  <dbl>     <dbl>
#  1 bipolarization FALSE               FALSE         0.00500 0.1000    0.05
#  2 bipolarization FALSE               FALSE         0.00500 0.1000    0.05
#  3 bipolarization FALSE               FALSE         0.00500 0.1000    0.05
#  4 bipolarization FALSE               FALSE         0.00500 0.1000    0.05
#  5 bipolarization FALSE               TRUE          0.00509 0.1000    0.05
#  6 bipolarization FALSE               TRUE          0.00509 0.1000    0.05
#  7 bipolarization FALSE               TRUE          0.00509 0.1000    0.05
#  8 bipolarization FALSE               TRUE          0.00509 0.1000    0.05
#  9 bipolarization TRUE                FALSE         0.00502 0.1000    0.0200
# 10 bipolarization TRUE                FALSE         0.00502 0.1000    0.0200
# # ℹ 28 more rows
# # ℹ 20 more variables: cr_min_sd <dbl>, ct_min <dbl>, ct_max <dbl>,
# #   ct_min_sd <dbl>, ct_max_sd <dbl>, rs_min <dbl>, rs_max <dbl>,
# #   rs_min_sd <dbl>, rs_max_sd <dbl>, rt_min <dbl>, rt_max <dbl>,
# #   rt_min_sd <dbl>, rt_max_sd <dbl>, nzw_min <dbl>, nzw_max <dbl>,
# #   best_mae <dbl>, mae_threshold_used <dbl>, n <int>, parameter <chr>,
# #   range_ok <lgl>
# [1] "Bipolarization constraint satisfied in all algorithm bounds"
# # A tibble: 4 × 7
#   model_type use_distinct_agents speaking_mode ct_max rt_min   gap constraint_ok
# * <chr>      <lgl>               <lgl>          <dbl>  <dbl> <dbl> <lgl>
# 1 bipolariz… FALSE               FALSE          0.300  0.400 0.100 TRUE
# 2 bipolariz… FALSE               TRUE           0.300  0.400 0.100 TRUE
# 3 bipolariz… TRUE                FALSE          0.300  0.400 0.100 TRUE
# 4 bipolariz… TRUE                TRUE           0.300  0.400 0.100 TRUE
# [11:05:59] Finished GA bounds creation
# [1] "\n// bipolarization | distinct: FALSE | speaking: FALSE | best_mae: 0.0094 | n: 8600"
# [2] "parameter \"Convergence Rate\" var: convergence_rate min: 0.005 max: 0.1;"
# [3] "parameter \"Confidence Threshold\" var: confidence_threshold min: 0.1 max: 0.3;"
# [4] "parameter \"Repulsion Strength\" var: repulsion_strength min: 0.05 max: 0.2;"
# [5] "parameter \"Repulsion Threshold\" var: repulsion_threshold min: 0.4 max: 0.7;"
# [6] "\n// bipolarization | distinct: FALSE | speaking: TRUE | best_mae: 0.0101 | n: 43003"
# [11:05:59] Starting Empirical model MLM for beta calculations...
# [11:05:59] Finished empirical MLM
# [11:05:59] Starting H2 uncentered model...
# boundary (singular) fit: see help('isSingular')
# [11:05:59] Finished H2 uncentered model...
# [11:05:59] Starting H2 centered model...
# boundary (singular) fit: see help('isSingular')
# [11:05:59] Finished H2 centered model...
# [11:06:01] DEBUG: sucessfully entered df_ag mutation block before lmer calculations
# [11:06:01] OLS vs ABM comparison initial mutation complete, starting df_ag slicing
# [DIAGNOSTIC] Starting empirical MLM pipeline...
#
#  -> Initial df_ag rows: 62909
#
#  -> Unique 'current_condition' levels (2): homogeneous, heterogeneous
#
#  -> Unique 'debate_label' count: 43
# [11:06:11] starting H1a df creation
# [11:06:11] Finished df creation, now starting H1a mlm...
# boundary (singular) fit: see help('isSingular')
# [11:06:11] H1b df setup starting...
# [11:06:12] Finished H1b df setup, starting mlm...
# boundary (singular) fit: see help('isSingular')
# [11:06:13] H1b df setup starting...
# [11:06:13] Finished H1b df setup, starting mlm...
# boundary (singular) fit: see help('isSingular')
# [11:06:14] H1b df setup starting...
# [11:06:14] Finished H1b df setup, starting mlm...
# boundary (singular) fit: see help('isSingular')
# [11:06:15] Skipping H1b for no_change - T1 equals T2 by definition
# [11:06:15] H3 benchmark: building test frame from sim_val$df_ag
# [11:06:15] test_frame: 59 rows, 12 debates
# [11:06:15] columns: model_type, current_condition, selected_debate_id, debate_label, current_experiment_id, max_cycles, use_distinct_agents, speaking_mode, logged_batch_seed, agent_id, pro_reduction, pro_count, anti_count, subfactor_1_t1, subfactor_2_t1, subfactor_3_t1, subfactor_4_t1, subfactor_5_t1, initial_opinion, initial_variance, opinion, subfactor_1_t2, subfactor_2_t2, subfactor_3_t2, subfactor_4_t2, subfactor_5_t2, final_attitude, mean_t2_subfactors, opinion_change, individual_error, error_sub1, error_sub2, error_sub3, error_sub4, error_sub5, agent_convergence_rate, agent_confidence_threshold, agent_repulsion_threshold, agent_repulsion_strength, total_influences_received, retention_discount, cumulative_opinion_change, agent_net_change, agent_wrong_direction, agent_is_saturated, convergence_rate, confidence_threshold, repulsion_threshold, repulsion_strength, convergence_cycle, converged, normalised_convergence, debate_composition, seed, design_cell, experiment_id_label, param_set_id, run_type, composition_scope, version, Condition, Time, Attitude
# [11:06:15] mlm_bench_h3 fixed effects: (Intercept)=0.0324, initial_opinion=0.959
# [11:06:15] mlm_pred range: 0.241 to 0.8793
# [11:06:15] initial_opinion range in test: 0.2176 to 0.8831
# [11:06:15] final_attitude range in test: 0.2049 to 0.8854
# [11:06:15] mlm_error summary — mean: 0.0474 range: 5e-04 to 0.139 NAs: 0
# [11:06:15] Set up H3a df and starting lmer call...
#
#  bipolarization
#    bipolarization_dist_nospeak: 6 wins, 0.0011 mean difference, 1.0000 p-value
#   bipolarization_dist_speak: 6 wins, -0.0001 mean difference, 1.0000 p-value
#   bipolarization_ndist_nospeak: 6 wins, 0.0002 mean difference, 1.0000 p-value
#   bipolarization_ndist_speak: 5 wins, -0.0002 mean difference, 0.7744 p-value
#
#  clustering
#    clustering_dist_nospeak: 6 wins, 0.0000 mean difference, 1.0000 p-value
#   clustering_dist_speak: 3 wins, 0.0018 mean difference, 0.1460 p-value
#   clustering_ndist_nospeak: 7 wins, -0.0010 mean difference, 0.7744 p-value
#   clustering_ndist_speak: 7 wins, -0.0001 mean difference, 0.7744 p-value
#
#  consensus
#    consensus_dist_nospeak: 6 wins, -0.0003 mean difference, 1.0000 p-value
#   consensus_dist_speak: 7 wins, -0.0004 mean difference, 0.7744 p-value
#   consensus_ndist_nospeak: 7 wins, -0.0002 mean difference, 0.7744 p-value
#   consensus_ndist_speak: 7 wins, -0.0004 mean difference, 0.7744 p-value
#
#  bipolarization
#    bipolarization_dist_nospeak: 6 wins, 0.0003 mean difference, 1.0000 p-value
#   bipolarization_dist_speak: 4 wins, -0.0008 mean difference, 0.3877 p-value
#   bipolarization_ndist_nospeak: 7 wins, -0.0006 mean difference, 0.7744 p-value
#   bipolarization_ndist_speak: 8 wins, -0.0010 mean difference, 0.3877 p-value
#
#  clustering
#    clustering_dist_nospeak: 5 wins, -0.0008 mean difference, 0.7744 p-value
#   clustering_dist_speak: 5 wins, 0.0010 mean difference, 0.7744 p-value
#   clustering_ndist_nospeak: 6 wins, -0.0018 mean difference, 1.0000 p-value
#   clustering_ndist_speak: 6 wins, -0.0009 mean difference, 1.0000 p-value
#
#  consensus
#    consensus_dist_nospeak: 6 wins, -0.0011 mean difference, 1.0000 p-value
#   consensus_dist_speak: 5 wins, -0.0012 mean difference, 0.7744 p-value
#   consensus_ndist_nospeak: 6 wins, -0.0010 mean difference, 1.0000 p-value
#   consensus_ndist_speak: 5 wins, -0.0012 mean difference, 0.7744 p-value
# [11:06:15] H5 df initialization
# [11:06:17] Starting branch C df setups, ols vs abm...
# [11:06:19] finished ols vs abm delta_mae calculations, starting empirical and simulated betas...
# DEBUG - complete cases count:
#
# DEBUG - df_conv_debate speaking_mode table:
# FALSE  TRUE  <NA>
#   172   129     0
# [1] 258

# %%
names(ga_outputs$results$comparisons$empirical)
str(ga_outputs$results$comparisons$empirical)
# Out:
# [1] "condition"         "mean_change_t0_t1" "sd_change_t0_t1"
# [4] "mean_change_t1_t2" "sd_change_t1_t2"   "mean_change_t0_t2"
# [7] "sd_change_t0_t2"   "n"
# tibble [3 × 8] (S3: tbl_df/tbl/data.frame)
#  $ condition        : chr [1:3] "Control" "Heterogeneous" "Homogeneous"
#  $ mean_change_t0_t1: num [1:3] 0.0436 0.0494 0.0833
#  $ sd_change_t0_t1  : num [1:3] 0.1018 0.1029 0.0978
#  $ mean_change_t1_t2: num [1:3] 0.0212 0.0185 -0.0128
#  $ sd_change_t1_t2  : num [1:3] 0.0567 0.0477 0.0637
#  $ mean_change_t0_t2: num [1:3] 0.0647 0.0679 0.0705
#  $ sd_change_t0_t2  : num [1:3] 0.117 0.103 0.102
#  $ n                : int [1:3] 187 176 92

# %%
# Empirical Data
## empirical bar chart for data change
## empirical_prep viz calls (bar chart for separate conditions and across them T0-T2)
### empirical_col & empirical_cross & empirical_cohen
cohen <- ga_outputs$results$comparisons$empirical_cohen
ca(sprintf("Pro-reduction effect (standardized β): %.3f\n", cohen$std_estimate))
cat(sprintf("Interpretatin: %s effect size\m",
            ifelse(abs(cohen$std_estimate) < 0.2, "small",
            ifelse(abs(cohen$std_estimate) > 0.5, "small-to-medium", "medium-plus"))))

# Plots
ga_outputs$plots$empirical_col() # rerun to cehck that scale fill manual is correctly commented out
ga_outputs$plots$empirical_cross()

# %% [markdown]
# # Empirical Data & Context

# %%
tidy(ga_outputs$results$models$mlm_h1a)
# Out:
# Error in `tidy()`:
# ! No `tidy()` method for objects of class <lmerMod>.
# Traceback:
#
# 1. tidy.default(ga_outputs$results$models$mlm_h1a)
# 2. cli::cli_abort("No {.fn tidy} method for objects of class {.cls {class(x)}}.")
# 3. rlang::abort(message, ..., call = call, use_cli_format = TRUE,
#  .     .frame = .frame)
# 4. signal_abort(cnd, .file)
# 5. signalCondition(cnd)

# %% [raw]
# # Hypothesis 1
# # Tables and MLM Stats
# broom.mixed::tidy(ga_outputs$results$models$mlm_h1a, conf.int = TRUE)
# lapply(ga_outputs$results$models$mlm_h1b, broom.mixed::tidy, conf.int = TRUE)
#
# ## mlm_h1b_viz & mlm_h1a_viz
# ga_outputs$plots$mlm_h1a_viz()
# # h1b
# for (m in ga_outputs$results$models$mlm_h1b) {
#   plot(check_model(m, check = c("linearity", "qq", "homogeneity")))
# }

# %% [markdown]
# # Hypothesis 1 Interpretation

# %%
# Hypothesis 2
# Tables and MLM Stats
broom.mixed::tidy(ga_outputs$results$models$mlm_h2, conf.int = TRUE)
broom.mixed::tidy(ga_outputs$results$models$mlm_h2_cent, conf.int = TRUE)

## mlm_h2_cent & mlm_h2
ga_outputs$plots$mlm_h2_viz()
ga_outputs$plots$mlm_h2_cent_viz()

# %% [markdown]
# # Hypothesis 2 Interpretation

# %%
# Hypothesis 3
## abm_vs_nc & abm_vs_mlm
## results$models$ df_h3a & df_h3b & mlm_bench_h3
# H3 Benchmark
broom.mixed::tidy(ga_outputs$results$models$mlm_bench_h3, conf.int = TRUE)

# H3a
broom.mixed::tidy(ga_outputs$results$models$mlm_h3a, conf.int = TRUE)
plot(check_model(ga_outputs$results$models$mlm_h3a, check = c("linearity", "qq", "homogeneity")))

# H3b
ga_outputs$results$comparisons$abm_vs_nc
ga_outputs$results$comparisons$abm_vs_mlm

# H5
ga_outputs$results$comparisons$df_h5
# Out:
#   effect   group        term            estimate   std.error  statistic
# 1 fixed    NA           (Intercept)     0.03235768 0.01409987  2.294893
# 2 fixed    NA           initial_opinion 0.95904291 0.02439352 39.315486
# 3 ran_pars debate_label sd__(Intercept) 0.02477066         NA        NA
# 4 ran_pars Residual     sd__Observation 0.04884191         NA        NA
#   conf.low    conf.high
# 1 0.004722449 0.05999291
# 2 0.911232503 1.00685333
# 3          NA         NA
# 4          NA         NA
# <0 x 0 matrix>
# Error in minfo$is_linear && !minfo$is_gam: type 'x' incorrect dans 'x && y'
# Traceback:
#
# 1. check_model(ga_outputs$results$models$mlm_h3a, check = c("linearity",
#  .     "qq", "homogeneity"))
# 2. check_model.default(ga_outputs$results$models$mlm_h3a, check = c("linearity",
#  .     "qq", "homogeneity"))
# 3. ifelse(minfo$is_linear && !minfo$is_gam, "normal", "simulated")
# 4. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "type 'x' incorrect dans 'x && y'", base::quote(minfo$is_linear &&
#  .     !minfo$is_gam))

# %% [markdown]
# # Hypothesis 3 Interpretation
# # describe mlm_h3a in one sentence (nothing differs from no_change)
#
# # h3b both comparison tables (describe the implications of mean difference)

# %%
# Hypothesis 4 
## could add to the framework file and create an object for it
## H4a
ga_outputs$results$comparisons$empirical

## H4b (new slot to compile in framework)

# %%
# Hypothesis 5
ga_outputs$results$models$df_h5

# %%
# RQ1 Set-up
